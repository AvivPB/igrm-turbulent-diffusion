# %%
import yt
import unyt
import caesar
import numpy as np

# %%
unyt.unyt_quantity(0, '')
# Out:
# unyt_quantity(0, '(dimensionless)')

# %%
unyt.epsilon_r
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 unyt.epsilon_r
#
# AttributeError: module 'unyt' has no attribute 'epsilon_r'

# %%
unyt.epsilon_kin
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 unyt.epsilon_kin
#
# AttributeError: module 'unyt' has no attribute 'epsilon_kin'

# %%
file = '/scratch/aspadawe/snapshots/HyenasC/L0/SimbaC_L0_Calibration/halo_3224_good-trillium/snapshot_151.hdf5'
snap = yt.load(file)
# Out:
# yt : [INFO     ] 2025-10-19 17:03:42,570 ComovingIntegrationOn does not exist, falling back to OmegaLambda
# yt : [INFO     ] 2025-10-19 17:03:42,584 Calculating time from 1.000e+00 to be 4.375e+17 seconds
# yt : [INFO     ] 2025-10-19 17:03:42,586 Assuming length units are in kpc/h (comoving)
# yt : [INFO     ] 2025-10-19 17:03:42,686 Parameters: current_time              = 4.3748565942961094e+17 s
# yt : [INFO     ] 2025-10-19 17:03:42,687 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-10-19 17:03:42,688 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-10-19 17:03:42,689 Parameters: domain_right_edge         = [200000. 200000. 200000.]
# yt : [INFO     ] 2025-10-19 17:03:42,690 Parameters: cosmological_simulation   = True
# yt : [INFO     ] 2025-10-19 17:03:42,691 Parameters: current_redshift          = 4.440892098500626e-16
# yt : [INFO     ] 2025-10-19 17:03:42,692 Parameters: omega_lambda              = 0.7
# ...

# %%
file = '/scratch/aspadawe/snapshots/HyenasC/L0/SimbaC_L0_Calibration/halo_3224_good-trillium/caesar_snap/caesar_151.hdf5'
obj = caesar.load(file)
# Out:
# yt : [INFO     ] 2025-10-19 17:08:36,702 Opening /scratch/aspadawe/snapshots/HyenasC/L0/SimbaC_L0_Calibration/halo_3224_good-trillium/caesar_snap/caesar_151.hdf5
# yt : [INFO     ] 2025-10-19 17:08:36,792 Found 3469 halos
# yt : [INFO     ] 2025-10-19 17:08:36,831 Found 292 galaxies

# %%
snap
# Out:
# GizmoDataset: /scratch/aspadawe/snapshots/HyenasC/L0/SimbaC_L0_Calibration/halo_3224_good-trillium/snapshot_151.hdf5

# %%
vars(snap)
# Out:
# {'storage_filename': None,
#  '_header': <yt.frontends.gadget.data_structures.GadgetBinaryHeader at 0x14b2f6c1d1d0>,
#  '_field_spec': ('Coordinates',
#   'Velocities',
#   'ParticleIDs',
#   'Mass',
#   ('InternalEnergy', 'Gas'),
#   ('Density', 'Gas'),
#   ('SmoothingLength', 'Gas')),
#  '_ptype_spec': ('Gas', 'Halo', 'Disk', 'Bulge', 'Stars', 'Bndry'),
#  '_id_dtype': 'u4',
#  'long_ids': False,
#  'header_offset': 0,
#  '_unit_base': {'length': (1.0, 'kpccm/h')},
#  'use_dark_factor': False,
#  'w_0': -1.0,
#  'w_a': 0.0,
#  'kernel_name': 'cubic',
#  'kdtree_filename': None,
#  'index_order': None,
#  'index_filename': None,
#  'dataset_type': 'gadget_hdf5',
#  'conversion_factors': {},
#  'parameters': {'BoxSize': np.float64(200000.0),
#   'Flag_Cooling': np.int32(1),
#   'Flag_DoublePrecision': np.int32(0),
#   'Flag_Feedback': np.int32(1),
#   'Flag_IC_Info': np.int32(3),
#   'Flag_Metals': np.int32(34),
#   'Flag_Sfr': np.int32(1),
#   'Flag_StellarAge': np.int32(1),
# ...

# %%
dir(snap)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_add_object_class',
#  '_arr',
#  '_assign_unit_system',
#  '_create_unit_registry',
#  '_determined_fields',
#  '_field_info_class',
#  '_field_spec',
#  '_file_class',
#  '_find_extremum',
#  '_force_periodicity',
#  '_get_field_info',
#  '_get_field_info_helper',
#  '_get_hvals',
#  '_get_uvals',
#  '_guess_candidates',
#  '_hash',
#  '_header',
#  '_id_dtype',
#  '_index_class',
# ...

# %%
snap.cosmology

# %%
snap.w_0
# Out:
# -1.0

# %%
snap.w_a
# Out:
# 0.0

# %%
snap.current_redshift
# Out:
# np.float64(4.440892098500626e-16)

# %%
snap.hubble_constant
# Out:
# np.float64(0.68)

# %%
snap.omega_matter
# Out:
# np.float64(0.3)

# %%
snap.critical_density
# Out:
# unyt_quantity(8.68605029e-30, 'g/cm**3')

# %%
snap.parameters
# Out:
# {'BoxSize': np.float64(200000.0),
#  'Flag_Cooling': np.int32(1),
#  'Flag_DoublePrecision': np.int32(0),
#  'Flag_Feedback': np.int32(1),
#  'Flag_IC_Info': np.int32(3),
#  'Flag_Metals': np.int32(34),
#  'Flag_Sfr': np.int32(1),
#  'Flag_StellarAge': np.int32(1),
#  'HubbleParam': np.float64(0.68),
#  'MassTable': array([0., 0., 0., 0., 0., 0.]),
#  'NumFilesPerSnapshot': np.int32(1),
#  'NumPart_ThisFile': array([2308404, 2561947, 2535062,       0,  192481,     576], dtype=uint32),
#  'NumPart_Total': array([2308404, 2561947, 2535062,       0,  192481,     576], dtype=uint32),
#  'NumPart_Total_HighWord': array([0, 0, 0, 0, 0, 0], dtype=uint32),
#  'Omega0': np.float64(0.3),
#  'OmegaLambda': np.float64(0.7),
#  'Redshift': np.float64(4.440892098500626e-16),
#  'Time': np.float64(0.9999999999999996),
#  'NumFiles': np.int32(1),
#  'Massarr': array([0., 0., 0., 0., 0., 0.])}

# %%
snap_data = snap.all_data()
# Out:
# yt : [INFO     ] 2025-10-19 18:00:21,520 Allocating for 7.598e+06 particles
# Loading particle index: 100%|██████████| 10/10 [00:00<00:00, 2126.93it/s]

# %%
snap_data['gas', 'H_nuclei_density'].units
# Out:
# cm**(-3)

# %%
print(f"'{snap_data['gas', 'H_nuclei_density'][100].units}'")
# Out:
# 'cm**(-3)'

# %%
snap_data['PartType0', 'DelayTime'].units
# Out:
# (dimensionless)

# %%
min(snap_data['PartType0', 'DelayTime'])
# Out:
# unyt_quantity(0., '(dimensionless)')

# %%
1e-12 >= 1e-20
# Out:
# True

# %%
obj

# %%
vars(obj)
# Out:
# {'_ds': None,
#  'data_file': '/scratch/aspadawe/snapshots/HyenasC/L0/SimbaC_L0_Calibration/halo_3224_good-trillium/caesar_snap/caesar_151.hdf5',
#  'skip_hash_check': False,
#  '_halo_dmlist': <caesar.loader.LazyDataset at 0x14b2f2174050>,
#  '_halo_slist': <caesar.loader.LazyDataset at 0x14b2f20d9e50>,
#  '_halo_glist': <caesar.loader.LazyDataset at 0x14b2f20d9f90>,
#  '_halo_bhlist': <caesar.loader.LazyDataset at 0x14b2f23f9f30>,
#  '_halo_dlist': <caesar.loader.LazyDataset at 0x14b2f23fa190>,
#  '_galaxy_slist': <caesar.loader.LazyDataset at 0x14b2f23f2c30>,
#  '_galaxy_glist': <caesar.loader.LazyDataset at 0x14b2f23d2be0>,
#  '_galaxy_bhlist': <caesar.loader.LazyDataset at 0x14b2f23d2cf0>,
#  '_galaxy_dlist': <caesar.loader.LazyDataset at 0x14b2f2127650>,
#  '_cloud_glist': <caesar.loader.LazyDataset at 0x14b2f2127750>,
#  '_cloud_dlist': <caesar.loader.LazyDataset at 0x14b2f213d7c0>,
#  'hash': 'df9ad2a0dbe450181c6f294c49596869',
#  'caesar': np.int64(315),
# ...

# %%
dir(obj)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cloud_data',
#  '_cloud_dicts',
#  '_cloud_dlist',
#  '_cloud_glist',
#  '_cloud_index_list',
#  '_ds',
#  '_galaxy_bhlist',
#  '_galaxy_data',
#  '_galaxy_dicts',
#  '_galaxy_dlist',
#  '_galaxy_glist',
#  '_galaxy_index_list',
#  '_galaxy_slist',
#  '_halo_bhlist',
#  '_halo_data',
#  '_halo_dicts',
#  '_halo_dlist',
#  '_halo_dmlist',
#  '_halo_glist',
#  '_halo_slist',
#  'caesar',
#  'central_galaxies',
#  'cloudinfo',
#  'clouds',
#  'data_file',
#  'galaxies',
#  'galinfo',
#  'haloinfo',
# ...
